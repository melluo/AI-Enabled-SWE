# %% [markdown]
# # Day 8 - Lab 1: Vision-Enabled UI/UX Agents
#
# **Objective:** Use multi-modal vision models to generate a frontend UI from a design image, and then use a second agent to perform an automated design review.
#
# **Estimated Time:** 90 minutes
#
# **Introduction:**
# Welcome to Day 8! Today, we'll explore one of the most exciting advancements in AI: vision. We will use a vision-capable model to act as a frontend developer, translating a design image directly into code. Then, we will create a second "UI/UX Critic" agent to automate the design review process, demonstrating a complete, AI-assisted frontend workflow.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# For this lab, we need to ensure we are using a vision-capable model. We will configure our `utils.py` helper to use a model like OpenAI's `gpt-4o` or Google's `gemini-2.5-pro`.
#
# **Model Selection:**
# This lab requires a vision-capable model. Excellent choices include `gpt-4o`, `gemini-2.5-pro`, or `deepseek-ai/DeepSeek-VL2`.
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client.
# - `get_vision_completion()`: A specialized function to send an image and a text prompt to a vision model.
# - `get_completion()`: To send text-only prompts for the refactoring step.
# - `save_artifact()`: To save the generated code and the design review.

# %%
import sys
import os

# Add the project's root directory to the Python path
try:
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_vision_completion, get_completion, save_artifact, clean_llm_output
from IPython.display import Image, display, Code

# Ensure you select a vision-capable model
client, model_name, api_provider = setup_llm_client(model_name="claude-opus-4-20250514")

if not model_name:
    print("Could not set up a valid LLM client. Please check your .env file and utils.py configuration.")
# Out:
# ✅ LLM Client configured: Using 'anthropic' with model 'claude-opus-4-20250514'

# %% [markdown]
# ## Step 2: The Design Screenshot
#
# This is the design we want our AI agent to build. It's a simple login form component. We will provide the URL to this image directly to the model.

# %%
login_form_url = "https://i.ibb.co/cf6nrv1/onboarding1.png"
display(Image(url=login_form_url))
# Out:
# <img src="https://i.ibb.co/cf6nrv1/onboarding1.png"/>

# %% [markdown]
# ## Step 3: The Challenges

# %% [markdown]
# ### Challenge 1 (Foundational): Generating a Monolithic UI Component
#
# **Task:** Use the vision model to generate a single, self-contained React component that replicates the design from the image.
#
# > **Tip for Vision Prompts:** Be specific about the output format. Telling the model you want 'React' and 'Tailwind CSS' is crucial. The more specific your technical constraints, the better the generated code will be.
#
# **Instructions:**
# 1.  Create a prompt that asks the vision model to act as an expert frontend developer.
# 2.  The prompt should instruct the model to analyze the image at the provided URL.
# 3.  Ask it to generate a single React component using Tailwind CSS for styling.
# 4.  The output should be a single block of JSX code.
#
# **Expected Quality:** A single file's worth of React code that, when rendered, visually approximates the login form in the screenshot.

# %%
# TODO: Write a prompt to generate a single React component from the image.
generate_ui_prompt = f"""
You are an expert UI/UX designer and React developer. Analyze the image at the following url {login_form_url} and do the following:
1. Generate a single React component that implements the UI shown in the image.
2. Use Tailwind CSS for styling.
3. Ensure the component is self-contained and when rendered, it should look close to the image.
4. Use material UI components where appropriate.
"""

print("--- Generating Monolithic UI Component ---")
if model_name:
    generated_monolithic_code = get_vision_completion(generate_ui_prompt, login_form_url, client, model_name, api_provider)
    cleaned_code = clean_llm_output(generated_monolithic_code, language='jsx')
    display(Code(cleaned_code, language='jsx'))
else:
    print("Skipping UI generation because no valid model is configured.")
    cleaned_code = ""

# Example monolithic JSX output for demonstration
example_monolithic_jsx = '''
import React from "react";
export default function LoginForm() {
  return (
    <div className="flex items-center justify-center min-h-screen bg-gray-100">
      <div className="bg-white p-8 rounded-lg shadow-md w-full max-w-sm">
        <h2 className="text-2xl font-bold mb-6 text-center">Sign In</h2>
        <form>
          <div className="mb-4">
            <label className="block text-gray-700 text-sm font-semibold mb-2" htmlFor="email">Email</label>
            <input
              className="w-full px-3 py-2 border rounded focus:outline-none focus:ring-2 focus:ring-blue-500"
              type="email"
              id="email"
              placeholder="Enter your email"
            />
          </div>
          <div className="mb-6">
            <label className="block text-gray-700 text-sm font-semibold mb-2" htmlFor="password">Password</label>
            <input
              className="w-full px-3 py-2 border rounded focus:outline-none focus:ring-2 focus:ring-blue-500"
              type="password"
              id="password"
              placeholder="Enter your password"
            />
          </div>
          <button
            type="submit"
            className="w-full bg-blue-600 text-white py-2 rounded hover:bg-blue-700 transition-colors font-semibold"
          >
            Sign In
          </button>
        </form>
      </div>
    </div>
  );
}
'''
display(Code(example_monolithic_jsx, language='jsx'))
# Out:
# --- Generating Monolithic UI Component ---
# import React from 'react';
# import {
#   Avatar,
#   Button,
#   Checkbox,
#   CircularProgress,
#   Box,
#   Typography,
#   IconButton,
#   Menu,
#   MenuItem,
# } from '@mui/material';
# import {
#   Home as HomeIcon,
#   Assignment as AssignmentIcon,
#   School as SchoolIcon,
#   Badge as BadgeIcon,
#   Settings as SettingsIcon,
#   MoreVert as MoreVertIcon,
#   Circle as CircleIcon,
# } from '@mui/icons-material';
#
# const OnboardingDashboard = () => {
#   const [anchorEl, setAnchorEl] = React.useState(null);
#   const [checkedTasks, setCheckedTasks] = React.useState({
#     benefits: false,
#     handbook: false,
#     workstation: false,
#   });
#
#   const handleMenuClick = (event) => {
#     setAnchorEl(event.currentTarget);
#   };
#
#   const handleMenuClose = () => {
#     setAnchorEl(null);
#   };
#
#   const handleTaskCheck = (task) => {
#     setCheckedTasks(prev => ({ ...prev, [task]: !prev[task] }));
#   };
#
#   const teamMembers = [
#     { name: 'Jane Cooper', role: 'Marketing Coordinator', completion: 75 },
#     { name: 'Ronald Richards', role: 'Sales Associate', completion: 'Overdue', isOverdue: true },
#     { name: 'Cody Fisher', role: 'Product Designer', completion: 60 },
#   ];
#
#   return (
#     <div className="min-h-screen bg-gray-100 p-6">
#       <div className="max-w-7xl mx-auto">
#         <div className="bg-white rounded-lg shadow-sm">
#           {/* Header */}
#           <div className="p-6 border-b border-gray-200 flex items-center justify-between">
#             <div className="flex items-center space-x-4">
#               <Avatar
#                 sx={{ width: 56, height: 56, bgcolor: '#2c3e50' }}
#                 src="/api/placeholder/56/56"
#               >
#                 S
#               </Avatar>
#               <h1 className="text-2xl font-semibold text-gray-800">
#                 Welcome, Sarah!
#               </h1>
#             </div>
#             <IconButton className="text-blue-500">
#               <CircleIcon />
#             </IconButton>
#           </div>
#
#           {/* Content */}
#           <div className="p-6">
#             <div className="grid grid-cols-1 lg:grid-cols-2 gap-8">
#               {/* Left Column - My Onboarding Overview */}
#               <div>
#                 <h2 className="text-lg font-semibold text-gray-800 mb-6">
#                   My Onboarding Overview
#                 </h2>
#
#                 {/* Progress Circle */}
#                 <div className="flex flex-col items-center mb-8">
#                   <Box position="relative" display="inline-flex">
#                     <CircularProgress
#                       variant="determinate"
#                       value={40}
#                       size={120}
#                       thickness={4}
#                       sx={{
#                         color: '#3b82f6',
#                         '& .MuiCircularProgress-circle': {
#                           strokeLinecap: 'round',
#                         },
#                       }}
#                     />
#                     <Box
#                       top={0}
#                       left={0}
#                       bottom={0}
#                       right={0}
#                       position="absolute"
#                       display="flex"
#                       alignItems="center"
#                       justifyContent="center"
#                     >
#                       <Typography
#                         variant="h4"
#                         component="div"
#                         color="text.secondary"
#                         className="font-semibold"
#                       >
#                         40%
#                       </Typography>
#                     </Box>
#                   </Box>
#                 </div>
#
#                 {/* Today's Tasks */}
#                 <div className="mb-6">
#                   <h3 className="text-base font-medium text-gray-700 mb-4">
#                     Today's Tasks
#                   </h3>
#                   <div className="space-y-3">
#                     <div className="flex items-center">
#                       <Checkbox
#                         checked={checkedTasks.benefits}
#                         onChange={() => handleTaskCheck('benefits')}
#                         sx={{ color: '#3b82f6' }}
#                       />
#                       <span className="text-gray-700">Complete Benefits Enrollment</span>
#                     </div>
#                     <div className="flex items-center justify-between">
#                       <div className="flex items-center">
#                         <Checkbox
#                           checked={checkedTasks.handbook}
#                           onChange={() => handleTaskCheck('handbook')}
#                           sx={{ color: '#3b82f6' }}
#                         />
#                         <span className="text-gray-700">Review Employee Handbook</span>
#                       </div>
#                       <span className="text-sm text-gray-500">Jul 26</span>
#                     </div>
#                     <div className="flex items-center justify-between">
#                       <div className="flex items-center">
#                         <Checkbox
#                           checked={checkedTasks.workstation}
#                           onChange={() => handleTaskCheck('workstation')}
#                           sx={{ color: '#3b82f6' }}
#                         />
#                         <span className="text-gray-700">Set Up Workstation</span>
#                       </div>
#                       <span className="text-sm text-gray-500">Jul 26</span>
#                     </div>
#                   </div>
#                 </div>
#
#                 {/* Continue Button */}
#                 <Button
#                   variant="contained"
#                   fullWidth
#                   sx={{
#                     bgcolor: '#3b82f6',
#                     '&:hover': { bgcolor: '#2563eb' },
#                     textTransform: 'none',
#                     py: 1.5,
#                     fontSize: '16px',
#                   }}
#                 >
#                   Continue Last Module
#                 </Button>
#               </div>
#
#               {/* Right Column - Team & HR Dashboard */}
#               <div>
#                 <h2 className="text-lg font-semibold text-gray-800 mb-6">
#                   Team & HR Dashboard
#                 </h2>
#
#                 {/* Team Members Table */}
#                 <div className="mb-6">
#                   <div className="grid grid-cols-3 gap-4 mb-4 text-sm text-gray-600 font-medium">
#                     <div>Name</div>
#                     <div>Role</div>
#                     <div>Completion</div>
#                   </div>
#
#                   <div className="space-y-4">
#                     {teamMembers.map((member, index) => (
#                       <div key={index} className="grid grid-cols-3 gap-4 items-center">
#                         <div className="text-gray-800">{member.name}</div>
#                         <div className="text-gray-600 text-sm">{member.role}</div>
#                         <div>
#                           {member.isOverdue ? (
#                             <span className="inline-flex items-center px-2.5 py-0.5 rounded-full text-xs font-medium bg-red-100 text-red-800">
#                               Overdue
#                             </span>
#                           ) : (
#                             <span className="text-gray-800 font-medium">{member.completion}%</span>
#                           )}
#                         </div>
#                       </div>
#                     ))}
#                   </div>
#                 </div>
#
#                 {/* Action Buttons */}
#                 <div className="space-y-3">
#                   <button className="w-full text-left px-4 py-3 border border-gray-300 rounded-lg hover:bg-gray-50 transition-colors">
#                     <span className="text-gray-700">Assign Role-Specific Task</span>
#                   </button>
#                   <button className="w-full text-left px-4 py-3 border border-gray-300 rounded-lg hover:bg-gray-50 transition-colors">
#                     <span className="text-gray-700">Send Reminder</span>
#                   </button>
#                   <button className="w-full text-left px-4 py-3 border border-gray-300 rounded-lg hover:bg-gray-50 transition-colors">
#                     <span className="text-gray-700">Collect Feedback</span>
#                   </button>
#                 </div>
#               </div>
#             </div>
#           </div>
#         </div>
#
#         {/* Sidebar */}
#         <div className="fixed left-0 top-0 h-full w-20 bg-white shadow-lg flex flex-col items-center py-8 space-y-6">
#           <IconButton sx={{ color: '#3b82f6' }}>
#             <HomeIcon />
#           </IconButton>
#           <IconButton sx={{ color: '#6b7280' }}>
#             <AssignmentIcon />
#           </IconButton>
#           <IconButton sx={{ color: '#6b7280' }}>
#             <SchoolIcon />
#           </IconButton>
#           <IconButton sx={{ color: '#6b7280' }}>
#             <BadgeIcon />
#           </IconButton>
#           <IconButton sx={{ color: '#6b7280' }}>
#             <SettingsIcon />
#           </IconButton>
#         </div>
#       </div>
#     </div>
#   );
# };
#
# export default OnboardingDashboard;

# %% [markdown]
# ### Challenge 2 (Intermediate): Refactoring into Reusable Components
#
# **Task:** A single, large component is not good practice. Now, prompt the LLM to refactor the monolithic code it just generated into smaller, reusable sub-components.
#
# **Instructions:**
# 1.  Create a new prompt.
# 2.  Provide the monolithic JSX code from the previous step as context.
# 3.  Instruct the LLM to act as a senior frontend developer who champions clean code.
# 4.  Ask it to refactor the code by creating smaller, reusable components (e.g., `<StyledButton>`, `<InputWithIcon>`).
# 5.  The final output should be the complete code with the new, smaller components defined and used within the main `Login` component.
#
# **Expected Quality:** A well-structured React file that demonstrates the component-based architecture, which is a fundamental best practice in modern frontend development.

# %%
# TODO: Write a prompt to refactor the monolithic code into smaller components.
refactor_ui_prompt = f"""
You are an expert UI/UX designer and React developer. Refactor the following monolithic React component {cleaned_code}
into smaller, reusable components. The goal is to break down the monolithic code into logical, manageable parts that can be reused across different parts of the application.
Ensure that each component has a clear purpose and follows best practices for React development.
"""

print("--- Refactoring UI into Components ---")
if cleaned_code:
    refactored_code = get_completion(refactor_ui_prompt, client, model_name, api_provider)
    cleaned_refactored_code = clean_llm_output(refactored_code, language='jsx')
    display(Code(cleaned_refactored_code, language='jsx'))
else:
    print("Skipping refactoring because monolithic code was not generated.")
    cleaned_refactored_code = ""
# Out:
# --- Refactoring UI into Components ---
# typescript
# // constants/onboarding.ts
# export const SIDEBAR_ITEMS = [
#   { icon: 'home', label: 'Home', isActive: true },
#   { icon: 'assignment', label: 'Tasks', isActive: false },
#   { icon: 'school', label: 'Learning', isActive: false },
#   { icon: 'badge', label: 'Achievements', isActive: false },
#   { icon: 'settings', label: 'Settings', isActive: false },
# ] as const;
#
# // types/onboarding.ts
# export interface TeamMember {
#   id: string;
#   name: string;
#   role: string;
#   completion: number | 'Overdue';
#   isOverdue?: boolean;
# }
#
# export interface Task {
#   id: string;
#   label: string;
#   checked: boolean;
#   dueDate?: string;
# }
#
# export interface UserProfile {
#   name: string;
#   avatar?: string;
#   initials: string;
# }
# ```
#
# ## 2. Sidebar Component
#
# ```tsx
# // components/layout/Sidebar.tsx
# import React from 'react';
# import { IconButton } from '@mui/material';
# import {
#   Home as HomeIcon,
#   Assignment as AssignmentIcon,
#   School as SchoolIcon,
#   Badge as BadgeIcon,
#   Settings as SettingsIcon,
# } from '@mui/icons-material';
#
# interface SidebarItem {
#   icon: string;
#   label: string;
#   isActive?: boolean;
#   onClick?: () => void;
# }
#
# interface SidebarProps {
#   items: SidebarItem[];
# }
#
# const iconMap = {
#   home: HomeIcon,
#   assignment: AssignmentIcon,
#   school: SchoolIcon,
#   badge: BadgeIcon,
#   settings: SettingsIcon,
# };
#
# export const Sidebar: React.FC<SidebarProps> = ({ items }) => {
#   return (
#     <div className="fixed left-0 top-0 h-full w-20 bg-white shadow-lg flex flex-col items-center py-8 space-y-6">
#       {items.map((item) => {
#         const Icon = iconMap[item.icon as keyof typeof iconMap];
#         return (
#           <IconButton
#             key={item.icon}
#             onClick={item.onClick}
#             sx={{ color: item.isActive ? '#3b82f6' : '#6b7280' }}
#             aria-label={item.label}
#           >
#             <Icon />
#           </IconButton>
#         );
#       })}
#     </div>
#   );
# };
# ```
#
# ## 3. Header Component
#
# ```tsx
# // components/dashboard/DashboardHeader.tsx
# import React from 'react';
# import { Avatar, IconButton } from '@mui/material';
# import { Circle as CircleIcon } from '@mui/icons-material';
# import { UserProfile } from '@/types/onboarding';
#
# interface DashboardHeaderProps {
#   user: UserProfile;
#   onNotificationClick?: () => void;
# }
#
# export const DashboardHeader: React.FC<DashboardHeaderProps> = ({
#   user,
#   onNotificationClick
# }) => {
#   return (
#     <div className="p-6 border-b border-gray-200 flex items-center justify-between">
#       <div className="flex items-center space-x-4">
#         <Avatar
#           sx={{ width: 56, height: 56, bgcolor: '#2c3e50' }}
#           src={user.avatar}
#           alt={user.name}
#         >
#           {user.initials}
#         </Avatar>
#         <h1 className="text-2xl font-semibold text-gray-800">
#           Welcome, {user.name}!
#         </h1>
#       </div>
#       <IconButton
#         className="text-blue-500"
#         onClick={onNotificationClick}
#         aria-label="Notifications"
#       >
#         <CircleIcon />
#       </IconButton>
#     </div>
#   );
# };
# ```
#
# ## 4. Progress Indicator Component
#
# ```tsx
# // components/common/CircularProgressIndicator.tsx
# import React from 'react';
# import { Box, CircularProgress, Typography } from '@mui/material';
#
# interface CircularProgressIndicatorProps {
#   value: number;
#   size?: number;
#   thickness?: number;
#   color?: string;
# }
#
# export const CircularProgressIndicator: React.FC<CircularProgressIndicatorProps> = ({
#   value,
#   size = 120,
#   thickness = 4,
#   color = '#3b82f6',
# }) => {
#   return (
#     <div className="flex flex-col items-center mb-8">
#       <Box position="relative" display="inline-flex">
#         <CircularProgress
#           variant="determinate"
#           value={value}
#           size={size}
#           thickness={thickness}
#           sx={{
#             color,
#             '& .MuiCircularProgress-circle': {
#               strokeLinecap: 'round',
#             },
#           }}
#         />
#         <Box
#           top={0}
#           left={0}
#           bottom={0}
#           right={0}
#           position="absolute"
#           display="flex"
#           alignItems="center"
#           justifyContent="center"
#         >
#           <Typography
#             variant="h4"
#             component="div"
#             color="text.secondary"
#             className="font-semibold"
#           >
#             {value}%
#           </Typography>
#         </Box>
#       </Box>
#     </div>
#   );
# };
# ```
#
# ## 5. Task List Component
#
# ```tsx
# // components/dashboard/TaskList.tsx
# import React from 'react';
# import { Checkbox } from '@mui/material';
# import { Task } from '@/types/onboarding';
#
# interface TaskListProps {
#   tasks: Task[];
#   onTaskToggle: (taskId: string) => void;
# }
#
# export const TaskList: React.FC<TaskListProps> = ({ tasks, onTaskToggle }) => {
#   return (
#     <div className="mb-6">
#       <h3 className="text-base font-medium text-gray-700 mb-4">
#         Today's Tasks
#       </h3>
#       <div className="space-y-3">
#         {tasks.map((task) => (
#           <div
#             key={task.id}
#             className="flex items-center justify-between"
#           >
#             <div className="flex items-center">
#               <Checkbox
#                 checked={task.checked}
#                 onChange={() => onTaskToggle(task.id)}
#                 sx={{ color: '#3b82f6' }}
#                 aria-label={`Mark ${task.label} as complete`}
#               />
#               <span className="text-gray-700">{task.label}</span>
#             </div>
#             {task.dueDate && (
#               <span className="text-sm text-gray-500">{task.dueDate}</span>
#             )}
#           </div>
#         ))}
#       </div>
#     </div>
#   );
# };
# ```
#
# ## 6. Team Members Table Component
#
# ```tsx
# // components/dashboard/TeamMembersTable.tsx
# import React from 'react';
# import { TeamMember } from '@/types/onboarding';
#
# interface TeamMembersTableProps {
#   members: TeamMember[];
# }
#
# const CompletionBadge: React.FC<{ member: TeamMember }> = ({ member }) => {
#   if (member.isOverdue) {
#     return (
#       <span className="inline-flex items-center px-2.5 py-0.5 rounded-full text-xs font-medium bg-red-100 text-red-800">
#         Overdue
#       </span>
#     );
#   }
#   return (
#     <span className="text-gray-800 font-medium">
#       {member.completion}%
#     </span>
#   );
# };
#
# export const TeamMembersTable: React.FC<TeamMembersTableProps> = ({ members }) => {
#   return (
#     <div className="mb-6">
#       <div className="grid grid-cols-3 gap-4 mb-4 text-sm text-gray-600 font-medium">
#         <div>Name</div>
#         <div>Role</div>
#         <div>Completion</div>
#       </div>
#
#       <div className="space-y-4">
#         {members.map((member) => (
#           <div key={member.id} className="grid grid-cols-3 gap-4 items-center">
#             <div className="text-gray-800">{member.name}</div>
#             <div className="text-gray-600 text-sm">{member.role}</div>
#             <div>
#               <CompletionBadge member={member} />
#             </div>
#           </div>
#         ))}
#       </div>
#     </div>
#   );
# };
# ```
#
# ## 7. Action Button Component
#
# ```tsx
# // components/common/ActionButton.tsx
# import React from 'react';
#
# interface ActionButtonProps {
#   label: string;
#   onClick: () => void;
#   variant?: 'primary' | 'secondary';
#   fullWidth?: boolean;
# }
#
# export const ActionButton: React.FC<ActionButtonProps> = ({
#   label,
#   onClick,
#   variant = 'secondary',
#   fullWidth = true
# }) => {
#   const baseClasses = "text-left px-4 py-3 rounded-lg transition-colors";
#   const variantClasses = variant === 'primary'
#     ? "bg-blue-500 text-white hover:bg-blue-600"
#     : "border border-gray-300 hover:bg-gray-50";
#   const widthClass = fullWidth ? "w-full" : "";
#
#   return (
#     <button
#       className={`${baseClasses} ${variantClasses} ${widthClass}`}
#       onClick={onClick}
#     >
#       <span className={variant === 'primary' ? 'text-white' : 'text-gray-700'}>
#         {label}
#       </span>
#     </button>
#   );
# };
# ```
#
# ## 8. Onboarding Overview Component
#
# ```tsx
# // components/dashboard/OnboardingOverview.tsx
# import React from 'react';
# import { Button } from '@mui/material';
# import { CircularProgressIndicator } from '@/components/common/CircularProgressIndicator';
# import { TaskList } from './TaskList';
# import { Task } from '@/types/onboarding';
#
# interface OnboardingOverviewProps {
#   progress: number;
#   tasks: Task[];
#   onTaskToggle: (taskId: string) => void;
#   onContinueModule: () => void;
# }
#
# export const OnboardingOverview: React.FC<OnboardingOverviewProps> = ({
#   progress,
#   tasks,
#   onTaskToggle,
#   onContinueModule,
# }) => {
#   return (
#     <div>
#       <h2 className="text-lg font-semibold text-gray-800 mb-6">
#         My Onboarding Overview
#       </h2>
#
#       <CircularProgressIndicator value={progress} />
#
#       <TaskList tasks={tasks} onTaskToggle={onTaskToggle} />
#
#       <Button
#         variant="contained"
#         fullWidth
#         onClick={onContinueModule}
#         sx={{
#           bgcolor: '#3b82f6',
#           '&:hover': { bgcolor: '#2563eb' },
#           textTransform: 'none',
#           py: 1.5,
#           fontSize: '16px',
#         }}
#       >
#         Continue Last Module
#       </Button>
#     </div>
#   );
# };
# ```
#
# ## 9. HR Dashboard Component
#
# ```tsx
# // components/dashboard/HRDashboard.tsx
# import React from 'react';
# import { TeamMembersTable } from './TeamMembersTable';
# import { ActionButton } from '@/components/common/ActionButton';
# import { TeamMember } from '@/types/onboarding';
#
# interface HRDashboardProps {
#   teamMembers: TeamMember[];
#   onAssignTask: () => void;
#   onSendReminder: () => void;
#   onCollectFeedback: () => void;
# }
#
# export const HRDashboard: React.FC<HRDashboardProps> = ({
#   teamMembers,
#   onAssignTask,
#   onSendReminder,
#   onCollectFeedback,
# }) => {
#   return (
#     <div>
#       <h2 className="text-lg font-semibold text-gray-800 mb-6">
#         Team & HR Dashboard
#       </h2>
#
#       <TeamMembersTable members={teamMembers} />
#
#       <div className="space-y-3">
#         <ActionButton
#           label="Assign Role-Specific Task"
#           onClick={onAssignTask}
#         />
#         <ActionButton
#           label="Send Reminder"
#           onClick={onSendReminder}
#         />
#         <ActionButton
#           label="Collect Feedback"
#           onClick={onCollectFeedback}
#         />
#       </div>
#     </div>
#   );
# };
# ```
#
# ## 10. Main Dashboard Container

# %% [markdown]
# ### Challenge 3 (Advanced): The AI UI/UX Critic Agent
#
# **Task:** Create a new "UI/UX Critic" agent. This agent will be given both the original design image and the generated code, and its job is to perform an automated design review.
#
# **Instructions:**
# 1.  Create a final, complex prompt for a new agent.
# 2.  The prompt should instruct the agent to act as a meticulous UI/UX designer.
# 3.  Provide the agent with two pieces of context: the URL of the original design image and the final, refactored React code.
# 4.  The agent's task is to compare the code's likely rendered output to the design image and list any visual inconsistencies in spacing, font size, color, or layout.
#
# **Expected Quality:** A critical design review in markdown format. This demonstrates a powerful AI-on-AI workflow, where one AI generates work and another AI validates it, automating a time-consuming QA step.

# %%
# TODO: Write a prompt for the UI/UX Critic agent.
critic_agent_prompt = f"""
You are a meticulous UI/UX designer and critic.
Critique the following refactored React component code {cleaned_refactored_code} based on the UI shown in the image at {login_form_url}.
Use your expertise to compare the code's likely rendered output to the design image and list any visual inconsistencies
in spacing, font size, color, layout, and overall design fidelity.
"""

print("--- Invoking UI/UX Critic Agent ---")
if cleaned_refactored_code:
    design_review = get_vision_completion(critic_agent_prompt, login_form_url, client, model_name, api_provider)
    display(Code(design_review, language='markdown'))
    save_artifact(design_review, "artifacts/design_review.md")
else:
    print("Skipping critic agent because refactored code is not available.")
# Out:
# --- Invoking UI/UX Critic Agent ---
# After analyzing the refactored React component code and comparing it to the UI design shown in the image, I've identified several visual inconsistencies and areas for improvement:
#
# ## Visual Inconsistencies
#
# ### 1. **Overall Layout Structure**
# - **Issue**: The code uses a fixed sidebar (`fixed left-0 top-0`), but the main content doesn't account for the sidebar width, potentially causing overlap
# - **Fix**: Main content should have `ml-20` to offset the 80px sidebar width
#
# ### 2. **Color Scheme Discrepancies**
# - **Sidebar Background**: Code uses white (`bg-white`), but the image shows a light gray/blue background (#e8eaf6 or similar)
# - **Active Icon Color**: Matches correctly with blue (#3b82f6)
# - **Header Avatar**: Code uses dark blue (#2c3e50), but image shows a lighter blue/purple shade
#
# ### 3. **Spacing Issues**
# - **Sidebar Icons**: Code has `space-y-6` (24px), but image shows tighter spacing (~16-20px)
# - **Content Padding**: The two main sections need more horizontal spacing between them
# - **Task List Items**: Spacing appears too tight in code compared to the airy design in the image
#
# ### 4. **Typography Inconsistencies**
# - **Welcome Message**: Font size seems correct but lacks the proper font weight variation shown in the image
# - **Section Headers**: "My Onboarding Overview" and "Team & HR Dashboard" appear to need more bottom margin
# - **Task Labels**: Missing the subtle gray color (#6b7280) shown in the image
#
# ### 5. **Progress Indicator**
# - **Size**: Code uses 120px, but the image shows a smaller indicator (~100px)
# - **Percentage Text**: The "40%" should be larger and bolder than current `variant="h4"`
#
# ### 6. **Team Table Layout**
# - **Grid Structure**: Code uses equal columns (grid-cols-3), but image shows uneven column widths
# - **Completion Column**: Needs right alignment as shown in image
# - **Row Spacing**: Too tight compared to the design
# - **Overdue Badge**: Correct implementation but needs size adjustment
#
# ### 7. **Buttons**
# - **Continue Module Button**: Correct color but needs more padding and rounded corners
# - **Action Buttons**: Missing hover states and proper border colors shown in the design
# - **Button Height**: All buttons appear shorter in code than in the design
#
# ### 8. **Missing Visual Elements**
# - **Card Container**: The entire dashboard should be wrapped in a white card with shadow
# - **Background**: Missing the light blue/gray background (#f5f7fb or similar)
# - **Divider Line**: Missing horizontal divider between header and content
#
# ### 9. **Task Checkboxes**
# - **Size**: Default MUI checkboxes might be too small compared to the design
# - **Due Dates**: Alignment issues - should be right-aligned
#
# ### 10. **Component Container Structure**
# ```tsx
# // Missing wrapper structure
# <div className="min-h-screen bg-gray-50"> {/* Missing background */}
#   <Sidebar />
#   <div className="ml-20"> {/* Missing offset */}
#     <div className="max-w-6xl mx-auto p-6"> {/* Missing container */}
#       <div className="bg-white rounded-lg shadow-sm"> {/* Missing card */}
#         {/* Content */}
#       </div>
#     </div>
#   </div>
# </div>
# ```
#
# ## Recommended Fixes
#
# ### 1. **Update Color Constants**
# ```tsx
# const colors = {
#   background: '#f5f7fb',
#   sidebar: '#e8eaf6',
#   primary: '#3b82f6',
#   text: {
#     primary: '#1a202c',
#     secondary: '#6b7280',
#   }
# };
# ```
#
# ### 2. **Fix Layout Structure**
# - Add proper container with margins and padding
# - Implement two-column grid for main content
# - Add consistent spacing tokens
#
# ### 3. **Typography Adjustments**
# - Increase section header font sizes
# - Add proper font weights
# - Implement consistent text colors
#
# ### 4. **Component Sizing**
# - Reduce progress indicator to ~100px
# - Increase button padding
# - Adjust checkbox sizes
#
# ### 5. **Add Missing UI Elements**
# - White card container with subtle shadow
# - Proper background color
# - Visual separators where needed
#
# The refactored code has good component separation and TypeScript implementation, but needs significant styling adjustments to match the visual design accurately.
# ✅ Successfully saved artifact to: artifacts/design_review.md

# %% [markdown]
# ## Lab Conclusion
#
# Fantastic! You have completed a full, end-to-end frontend development workflow using multiple AI agents. You used a vision-powered agent to generate code from a design, a refactoring agent to improve the code's structure, and a critic agent to perform an automated design review. This powerful combination of skills can dramatically accelerate the process of turning visual ideas into functional user interfaces.
#
# > **Key Takeaway:** The workflow of **Generate -> Refactor -> Critique** is a powerful AI-assisted development pattern. Using specialized agents for each step allows you to rapidly create a first draft, improve its quality, and then automatically check it for correctness, significantly speeding up the iteration cycle.
